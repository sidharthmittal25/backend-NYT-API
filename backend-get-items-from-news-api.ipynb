# %%
import argparse
import logging
import requests

log = logging.getLogger(__name__)


class NYTimesSource(object):
    """
    A data loader plugin for the NY Times API.
    """

    def __init__(self):
        pass

    def connect(self, inc_column=None, max_inc_value=None):
        log.debug("Incremental Column: %r", inc_column)
        log.debug("Incremental Last Value: %r", max_inc_value)

    def disconnect(self):
        """Disconnect from the source."""
        # Nothing to do
        pass
    
    def getKeywords(self, keywordList):
        keyValueList = []
        for keyword in keywordList:
            keyValueList.append(keyword["value"])
        
        return keyList

    def get_news_items(self, api_key, query, page):
        url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"
        params = {
            "api-key": api_key,
            "q": query,
            "page": page
        }

        response = requests.get(url, params=params)
        data = response.json()
        
        news_items = []
        if "response" in data and "docs" in data["response"]:
            for doc in data["response"]["docs"]:
                news_item = {
                    "title": doc["headline"]["main"],
                    "body": doc["snippet"],
                    "web_url": doc["web_url"],
                    "created_at": doc["pub_date"],
                    "id": doc["_id"],
                    "abstract": doc["abstract"],
                    "keywords": getKeywords(doc["keywords"])                   
                }
                news_items.append(news_item)

        return news_items

    def getDataBatch(self, batch_size):
        """
        Generator - Get data from source on batches.

        :returns One list for each batch. Each of those is a list of
                 dictionaries with the defined rows.
        """
        api_key = self.args.api_key
        query = self.args.query

        page = 0
        while True:
            news_items = self.get_news_items(api_key, query, page)
            if not news_items:
                break
            yield news_items
            page += 1
            if page * 10 >= batch_size:
                break

    def getSchema(self):
        """
        Return the schema of the dataset
        :returns a List containing the names of the columns retrieved from the
        source
        """

        schema = [
            "title",
            "body",
            "created_at",
            "id",
            "summary",
            "abstract",
            "keywords",
        ]

        return schema


if __name__ == "__main__":
    config = {
        "api_key": "LbD28ygn59tisg1YBCQ6uEmY5YIQ1M5S",
        "query": "Silicon Valley",
    }
    source = NYTimesSource()

    # This looks like an argparse dependency - but the Namespace class is just
    # a simple way to create an object holding attributes.
    source.args = argparse.Namespace(**config)
    
    for idx, batch in enumerate(source.getDataBatch(10)):
        print(f"{idx} Batch of {len(batch)} items")
        print("The full batch is as follow: \n")
        print(batch)
        print("\n")
        print("Values in the batch are as follow: \n")
        for item in batch:
            print(item)
# Out:
# 0 Batch of 10 items
# The full batch is as follow:
#
# [{'title': 'Silicon Valley, Cradle of Computer Chips, Gains Big New Research Center', 'body': 'Anticipating federal subsidies, Applied Materials said it planned to invest up to $4 billion in the semiconductor project in Sunnyvale, Calif.', 'web_url': 'https://www.nytimes.com/2023/05/22/technology/applied-materials-silicon-valley.html', 'created_at': '2023-05-22T09:00:14+0000', 'id': 'nyt://article/d476130a-57be-53c6-9efe-3bb61a42e8c7', 'abstract': 'Anticipating federal subsidies, Applied Materials said it planned to invest up to $4 billion in the semiconductor project in Sunnyvale, Calif.', 'keywords': ['Research', 'Computers and the Internet', 'Factories and Manufacturing', 'Computer Chips', 'Innovation', 'Engineering and Engineers', 'Applied Materials Inc', 'Silicon Valley (Calif)']}, {'title': 'Regulators Rebut Claims by Silicon Valley Bank’s Ex-C.E.O.', 'body': 'The bank had not fixed its problems before it failed, they said. Its leader was not excluded from the sale process.', 'web_url': 'https://www.nytimes.com/2023/05/18/business/silicon-valley-bank-becker-regulators.html', 'created_at': '2023-05-18T20:58:33+0000', 'id': 'nyt://article/e0f52b03-1131-51ef-9b03-19869fdd7a05', 'abstract': 'The bank had not fixed its problems before it failed, they said. Its leader was not excluded from the sale process.', 'keywords': ['Regulation and Deregulation of Industry', 'Banking and Financial Institutions', 'Senate Committee on Banking', 'Silicon Valley Bank', 'Becker, Gregory W']}, {'title': 'Senators Grill Ex-C.E.O. of Silicon Valley Bank', 'body': 'Lawmakers on the Senate Banking Committee derided claims by the former chief executive of Silicon Valley Bank, Gregory Becker, that unforeseeable circumstances led to the bank’s failure.', 'web_url': 'https://www.nytimes.com/video/business/100000008909266/silicon-valley-bank-senate.html', 'created_at': '2023-05-16T19:58:20+0000', 'id': 'nyt://video/72709f83-a587-530b-a27d-0a4541831463', 'abstract': 'Lawmakers on the Senate Banking Committee derided claims by the former chief executive of Silicon Valley Bank, Gregory Becker, that unforeseeable circumstances led to the bank’s failure.', 'keywords': ['Becker, Gregory W', 'Silicon Valley Bank', 'Banking and Financial Institutions', 'Senate', 'Brown, Sherrod', 'Kennedy, John Neely', 'United States Politics and Government', 'Senate Committee on Banking']}, {'title': '‘Do You Even Want Us to Exist?’ A Bank Chief Fights to Survive.', 'body': 'The banks at the center of the recent crisis, like Western Alliance, are engaged in collective soul-searching.', 'web_url': 'https://www.nytimes.com/2023/06/14/business/western-alliance-regional-banks.html', 'created_at': '2023-06-14T14:26:00+0000', 'id': 'nyt://article/55fdee84-0cbc-54f1-ac30-d47fc40304ca', 'abstract': 'The banks at the center of the recent crisis, like Western Alliance, are engaged in collective soul-searching.', 'keywords': ['Banking and Financial Institutions', 'Credit and Debt', 'Shutdowns (Institutional)', 'Stocks and Bonds', 'Western Alliance Bancorp', 'Silicon Valley Bank', 'First Republic Bank', 'United States Economy', 'Regulation and Deregulation of Industry', 'Treasury Department']}, {'title': 'Savoring a California Wine Country Far From Napa and the Crowds', 'body': 'A growing patchwork of small and bucolic wineries an hour’s drive south from Silicon Valley are making and serving prizewinning chardonnay, pinot noir and other estate vintages.', 'web_url': 'https://www.nytimes.com/2023/06/12/travel/silicon-valley-south-bay-wine-vineyards.html', 'created_at': '2023-06-12T09:00:40+0000', 'id': 'nyt://article/b5593cdb-0b4e-5904-a240-523a8a8b3d89', 'abstract': 'A growing patchwork of small and bucolic wineries an hour’s drive south from Silicon Valley are making and serving prizewinning chardonnay, pinot noir and other estate vintages.', 'keywords': ['Wines', 'California', 'Gilroy (Calif)', 'Santa Clara (Calif)', 'Santa Cruz (Calif)', 'Silicon Valley (Calif)', 'Travel and Vacations ...
#
#
# Values in the batch are as follow:
#
# {'title': 'Silicon Valley, Cradle of Computer Chips, Gains Big New Research Center', 'body': 'Anticipating federal subsidies, Applied Materials said it planned to invest up to $4 billion in the semiconductor project in Sunnyvale, Calif.', 'web_url': 'https://www.nytimes.com/2023/05/22/technology/applied-materials-silicon-valley.html', 'created_at': '2023-05-22T09:00:14+0000', 'id': 'nyt://article/d476130a-57be-53c6-9efe-3bb61a42e8c7', 'abstract': 'Anticipating federal subsidies, Applied Materials said it planned to invest up to $4 billion in the semiconductor project in Sunnyvale, Calif.', 'keywords': ['Research', 'Computers and the Internet', 'Factories and Manufacturing', 'Computer Chips', 'Innovation', 'Engineering and Engineers', 'Applied Materials Inc', 'Silicon Valley (Calif)']}
# {'title': 'Regulators Rebut Claims by Silicon Valley Bank’s Ex-C.E.O.', 'body': 'The bank had not fixed its problems before it failed, they said. Its leader was not excluded from the sale process.', 'web_url': 'https://www.nytimes.com/2023/05/18/business/silicon-valley-bank-becker-regulators.html', 'created_at': '2023-05-18T20:58:33+0000', 'id': 'nyt://article/e0f52b03-1131-51ef-9b03-19869fdd7a05', 'abstract': 'The bank had not fixed its problems before it failed, they said. Its leader was not excluded from the sale process.', 'keywords': ['Regulation and Deregulation of Industry', 'Banking and Financial Institutions', 'Senate Committee on Banking', 'Silicon Valley Bank', 'Becker, Gregory W']}
# {'title': 'Senators Grill Ex-C.E.O. of Silicon Valley Bank', 'body': 'Lawmakers on the Senate Banking Committee derided claims by the former chief executive of Silicon Valley Bank, Gregory Becker, that unforeseeable circumstances led to the bank’s failure.', 'web_url': 'https://www.nytimes.com/video/business/100000008909266/silicon-valley-bank-senate.html', 'created_at': '2023-05-16T19:58:20+0000', 'id': 'nyt://video/72709f83-a587-530b-a27d-0a4541831463', 'abstract': 'Lawmakers on the Senate Banking Committee derided claims by the former chief executive of Silicon Valley Bank, Gregory Becker, that unforeseeable circumstances led to the bank’s failure.', 'keywords': ['Becker, Gregory W', 'Silicon Valley Bank', 'Banking and Financial Institutions', 'Senate', 'Brown, Sherrod', 'Kennedy, John Neely', 'United States Politics and Government', 'Senate Committee on Banking']}
# {'title': '‘Do You Even Want Us to Exist?’ A Bank Chief Fights to Survive.', 'body': 'The banks at the center of the recent crisis, like Western Alliance, are engaged in collective soul-searching.', 'web_url': 'https://www.nytimes.com/2023/06/14/business/western-alliance-regional-banks.html', 'created_at': '2023-06-14T14:26:00+0000', 'id': 'nyt://article/55fdee84-0cbc-54f1-ac30-d47fc40304ca', 'abstract': 'The banks at the center of the recent crisis, like Western Alliance, are engaged in collective soul-searching.', 'keywords': ['Banking and Financial Institutions', 'Credit and Debt', 'Shutdowns (Institutional)', 'Stocks and Bonds', 'Western Alliance Bancorp', 'Silicon Valley Bank', 'First Republic Bank', 'United States Economy', 'Regulation and Deregulation of Industry', 'Treasury Department']}
# {'title': 'Savoring a California Wine Country Far From Napa and the Crowds', 'body': 'A growing patchwork of small and bucolic wineries an hour’s drive south from Silicon Valley are making and serving prizewinning chardonnay, pinot noir and other estate vintages.', 'web_url': 'https://www.nytimes.com/2023/06/12/travel/silicon-valley-south-bay-wine-vineyards.html', 'created_at': '2023-06-12T09:00:40+0000', 'id': 'nyt://article/b5593cdb-0b4e-5904-a240-523a8a8b3d89', 'abstract': 'A growing patchwork of small and bucolic wineries an hour’s drive south from Silicon Valley are making and serving prizewinning chardonnay, pinot noir and other estate vintages.', 'keywords': ['Wines', 'California', 'Gilroy (Calif)', 'Santa Clara (Calif)', 'Santa Cruz (Calif)', 'Silicon Valley (Calif)', 'Travel and Vacations', 'Chardonnay (Wine)', 'Pinot Noir (Wine)']}
# {'title': 'Silicon Valley Bank’s Ex-C.E.O. Is ‘Truly Sorry’ but Deflects Blame', 'body': 'Senators derided Gregory Becker at a hearing about the reasons for the failure of his bank. “It sounds a lot like ‘my dog ate my homework,’” one said.', 'web_url': 'https://www.nytimes.com/2023/05/16/business/silicon-valley-bank-becker-testimony.html', 'created_at': '2023-05-16T17:15:52+0000', 'id': 'nyt://article/7d2205b6-09cb-5986-80d6-7dffdf41cde6', 'abstract': 'Senators derided Gregory Becker at a hearing about the reasons for the failure of his bank. “It sounds a lot like ‘my dog ate my homework,’” one said.', 'keywords': ['Silicon Valley Bank', 'Becker, Gregory W', 'Shay, Scott A', 'Signature Bank', 'Regulation and Deregulation of Industry', 'Banking and Financial Institutions', 'Government Bonds', 'Federal Reserve System', 'Senate Committee on Banking', 'United States Politics and Government', 'Executive Compensation']}
# {'title': 'A Week With the Wild Children of the A.I. Boom', 'body': 'In Silicon Valley’s hacker houses, the latest crop of young entrepreneurs is partying, innovating — and hoping not to get crushed by the big guys.', 'web_url': 'https://www.nytimes.com/2023/05/31/magazine/ai-start-up-accelerator-san-francisco.html', 'created_at': '2023-05-31T08:57:13+0000', 'id': 'nyt://article/a6ed8ce3-c7af-54d9-9649-bad2ae480fec', 'abstract': 'In Silicon Valley’s hacker houses, the latest crop of young entrepreneurs is partying, innovating — and hoping not to get crushed by the big guys.', 'keywords': ['Artificial Intelligence', 'Start-ups', 'ChatGPT', 'OpenAI Labs', 'Computers and the Internet', 'Venture Capital', 'Entrepreneurship', 'Silicon Valley (Calif)', 'internal-sub-only']}
# {'title': 'Reid Hoffman Is on a Mission: To Show A.I. Can Improve Humanity', 'body': 'Few are as involved in so many different artificial intelligence efforts as Mr. Hoffman, a Silicon Valley investor who co-founded LinkedIn.', 'web_url': 'https://www.nytimes.com/2023/05/25/technology/reid-hoffman-artificial-intelligence.html', 'created_at': '2023-05-25T09:00:33+0000', 'id': 'nyt://article/676c6476-f1d9-5926-bd30-25307731dbb6', 'abstract': 'Few are as involved in so many different artificial intelligence efforts as Mr. Hoffman, a Silicon Valley investor who co-founded LinkedIn.', 'keywords': ['Hoffman, Reid Garrett', 'Greylock Partners', 'Artificial Intelligence', 'Computers and the Internet', 'Venture Capital', 'Start-ups', 'Boards of Directors', 'Entrepreneurship', 'Innovation', 'Inflection AI Inc', 'Microsoft Corp', 'OpenAI Labs', 'Silicon Valley (Calif)']}
# {'title': 'Fed Officials Were Split Over June Rate Pause, Minutes Show', 'body': 'In the Federal Reserve’s last meeting, “several” participants thought rates may have moved high enough to get inflation under control.', 'web_url': 'https://www.nytimes.com/2023/05/24/us/politics/federal-reserve-minutes.html', 'created_at': '2023-05-24T20:15:45+0000', 'id': 'nyt://article/ee48909c-7cfc-5954-9833-09df6343aeaf', 'abstract': 'In the Federal Reserve’s last meeting, “several” participants thought rates may have moved high enough to get inflation under control.', 'keywords': ['Banking and Financial Institutions', 'Inflation (Economics)', 'Interest Rates', 'United States Economy', 'Prices (Fares, Fees and Rates)', 'Labor and Jobs', 'National Debt (US)', 'Federal Reserve System', 'Silicon Valley Bank', 'Signature Bank', 'Kashkari, Neel T']}
# {'title': 'Goldman Says U.S. Is Investigating Its Work for Silicon Valley Bank', 'body': 'Hired to help with a capital raise, Goldman Sachs advised SVB to make a move that provoked a public panic and ended with the smaller bank collapsing.', 'web_url': 'https://www.nytimes.com/2023/05/04/business/goldman-svb-investigation.html', 'created_at': '2023-05-04T15:49:15+0000', 'id': 'nyt://article/fb40663f-a9fe-5ede-a6a5-491154b59032', 'abstract': 'Hired to help with a capital raise, Goldman Sachs advised SVB to make a move that provoked a public panic and ended with the smaller bank collapsing.', 'keywords': ['Regulation and Deregulation of Industry', 'Banking and Financial Institutions', 'Stocks and Bonds', 'Mergers, Acquisitions and Divestitures', 'First Republic Bank', 'Goldman Sachs Group Inc', 'Silicon Valley Bank']}
